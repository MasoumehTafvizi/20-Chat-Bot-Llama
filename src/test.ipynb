# %%
from ollama import chat
from ollama import ChatResponse



def call_llama(model, prompt, stream=True):
    if stream:
        stream = chat(
            model=model,
            messages=[{'role': 'user', 'content': prompt}],
            stream=True,
        )
        full_text = "" 
        for chunk in stream:
            content = chunk.message.content or ""
            print(content, end='', flush=True)
            full_text += content
        return full_text
    
    else:
        response: ChatResponse = chat(model=model, messages=[
            {
                'role': 'user',
                'content': prompt,
            },
            ])
        return response.message.content

# %%
call_llama("qwen2.5:3b-instruct", "Hi",True)
# Out:
# Hello! How can I assist you today? Feel free to ask any questions or let me know if you need information on a particular topic.
# 'Hello! How can I assist you today? Feel free to ask any questions or let me know if you need information on a particular topic.'
